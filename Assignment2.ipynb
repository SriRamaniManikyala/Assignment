# %% [markdown]
# Load the data into a Python session as a Pandas DataFrame. Check if all columns are in correct type, and fix any incorrect ones if necessary

# %%
import pandas as pd

df = pd.read_csv('/content/auto-mpg.csv')

df
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0    3504          12.0
# 1    15.0          8         350.0       165.0    3693          11.5
# 2    18.0          8         318.0       150.0    3436          11.0
# 3    16.0          8         304.0       150.0    3433          12.0
# 4    17.0          8         302.0       140.0    3449          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0        86.0    2790          15.6
# 394  44.0          4          97.0        52.0    2130          24.6
# 395  32.0          4         135.0        84.0    2295          11.6
# 396  28.0          4         120.0        79.0    2625          18.6
# 397  31.0          4         119.0        82.0    2720          19.4
#
#      model year  origin                   car name
# 0            70       1  chevrolet chevelle malibu
# ...

# %% [markdown]
# 2.Split the data 75% training and 25% testing

# %%
# import packages
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# Step 1: Load the data into a Pandas DataFrame
data = pd.read_csv('auto-mpg.csv')

# %%
data
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0    3504          12.0
# 1    15.0          8         350.0       165.0    3693          11.5
# 2    18.0          8         318.0       150.0    3436          11.0
# 3    16.0          8         304.0       150.0    3433          12.0
# 4    17.0          8         302.0       140.0    3449          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0        86.0    2790          15.6
# 394  44.0          4          97.0        52.0    2130          24.6
# 395  32.0          4         135.0        84.0    2295          11.6
# 396  28.0          4         120.0        79.0    2625          18.6
# 397  31.0          4         119.0        82.0    2720          19.4
#
#      model year  origin                   car name
# 0            70       1  chevrolet chevelle malibu
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           398 non-null    float64
#  1   cylinders     398 non-null    int64
#  2   displacement  398 non-null    float64
#  3   horsepower    392 non-null    float64
#  4   weight        398 non-null    int64
#  5   acceleration  398 non-null    float64
#  6   model year    398 non-null    int64
#  7   origin        398 non-null    int64
#  8   car name      398 non-null    object
# dtypes: float64(4), int64(4), object(1)
# memory usage: 28.1+ KB

# %%
# Step 2: Split the data into training (75%) and testing (25%)
from sklearn.model_selection import train_test_split
train, test = train_test_split(data, test_size=0.25, random_state=42)

# %%
train
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 245  36.1          4          98.0        66.0    1800          14.4
# 110  22.0          4         108.0        94.0    2379          16.5
# 16   18.0          6         199.0        97.0    2774          15.5
# 66   17.0          8         304.0       150.0    3672          11.5
# 153  18.0          6         250.0       105.0    3459          16.0
# ..    ...        ...           ...         ...     ...           ...
# 71   19.0          3          70.0        97.0    2330          13.5
# 106  12.0          8         350.0       180.0    4499          12.5
# 270  21.1          4         134.0        95.0    2515          14.8
# 348  37.7          4          89.0        62.0    2050          17.3
# 102  26.0          4          97.0        46.0    1950          21.0
#
#      model year  origin                   car name
# 245          78       1                ford fiesta
# ...

# %%
test.head()
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 198  33.0          4          91.0        53.0    1795          17.4
# 396  28.0          4         120.0        79.0    2625          18.6
# 33   19.0          6         232.0       100.0    2634          13.0
# 208  13.0          8         318.0       150.0    3940          13.2
# 93   14.0          8         318.0       150.0    4237          14.5
#
#      model year  origin                    car name
# 198          76       3                 honda civic
# 396          82       1                 ford ranger
# 33           71       1                 amc gremlin
# 208          76       1  plymouth volare premier v8
# 93           73       1    plymouth fury gran sedan

# %%
data.columns
# Out:
# Index(['mpg', 'cylinders', 'displacement', 'horsepower', 'weight',
#        'acceleration', 'model year', 'origin', 'car name'],
#       dtype='object')

# %%
continues_val=['mpg','displacement','horsepower','weight','acceleration']

# %%
for x in continues_val:
    print("plotting ",x," column")
    f = plt.figure()
    f.set_figwidth(15)
    f.set_figheight(5)
    plt.plot(data[x])
    plt.xlabel("Nth record")
    plt.ylabel(x)
    plt.show()
# Out:
# plotting  mpg  column
# plotting  displacement  column
# plotting  horsepower  column
# plotting  weight  column
# plotting  acceleration  column

# %% [markdown]
# Columns that are numeric and have symmetric distributions
#
# Columns that are numeric and have skewed distributions
#
# Columns that are categorical

# %%
# Step 3: Visualize necessary columns and categorize them
numeric_columns_symmetric = ['mpg', 'acceleration']
numeric_columns_skewed = ['cylinders', 'displacement', 'horsepower', 'weight', 'model year']
categorical_columns = ['origin', 'car name']

# %%
# Plot histograms for numeric columns
for col in numeric_columns_symmetric + numeric_columns_skewed:
    plt.figure(figsize=(8, 4))
    plt.hist(train[col], bins=20, edgecolor='k')
    plt.title(f'Histogram of {col}')
    plt.xlabel(col)
    plt.ylabel('Frequency')
    plt.show()

# Plot bar charts for categorical columns
for col in categorical_columns:
    plt.figure(figsize=(25, 5))
    train[col].value_counts().plot(kind='bar')
    plt.title(f'Bar Chart of {col}')
    plt.xlabel(col)
    plt.ylabel('Count')
    plt.show()

# %%
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import FunctionTransformer
import numpy as np

# Define a function to apply log transformation to numeric columns
def log_transform(X):
    return np.log1p(X)

# Define column groups
numeric_columns_symmetric = ['mpg', 'acceleration']
numeric_columns_skewed = ['cylinders', 'displacement', 'horsepower', 'weight', 'model year']
categorical_columns = ['origin', 'car name']

# Create transformers for each column group
numeric_symmetric_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='mean')),
    ('scaler', StandardScaler())
])

numeric_skewed_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='mean')),
    ('log_transform', FunctionTransformer(log_transform)),
    ('scaler', StandardScaler())
])

categorical_transformer = Pipeline(steps=[
    ('onehot', OneHotEncoder(handle_unknown='ignore'))
])



# Combine transformers using ColumnTransformer
preprocessor = ColumnTransformer(
    transformers=[
        ('num_symmetric', numeric_symmetric_transformer, numeric_columns_symmetric),
        ('num_skewed', numeric_skewed_transformer, numeric_columns_skewed),
        ('cat', categorical_transformer, categorical_columns)
    ])




# Create the final pipeline
pipeline = Pipeline(steps=[('preprocessor', preprocessor)])

# Transform the data using the pipeline
X_train_transformed = pipeline.fit_transform(train)
X_test_transformed = pipeline.transform(test)

# %%
X_train_transformed.shape
# Out:
# (298, 242)

# %%
X_test_transformed.shape
# Out:
# (100, 242)
